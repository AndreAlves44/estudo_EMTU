# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
arquivo = '/content/drive/MyDrive/Estudo-EMTU.csv'
with open(arquivo, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 50):
      print(f'Linha {i+1}: {linhas[i]}')
# Out:
# Linha 1: Mes-Ano,PAX,COVID,PNAD-Ocupacao,PNAD-Desemprego,ANFAVEA-VendaVeiculos
#
# Linha 2: Jan-19,1702854,0,56,12.2,175856
#
# Linha 3: fev-19,1654235,0,55,12.6,176695
#
# Linha 4: Mar-19,1792998,0,55,12.8,186204
#
# Linha 5: abr-19,1852567,0,56,12.6,205774
#
# Linha 6: mai-19,1930302,0,56,12.4,219849
#
# Linha 7: Jun-19,1690321,0,56,12.1,200479
#
# Linha 8: Jul-19,1713129,0,56,12,218492
#
# Linha 9: ago-19,1881300,0,56,11.9,216858
#
# Linha 10: set-19,1827545,0,56,11.9,210017
#
# Linha 11: out-19,1961792,0,56,11.8,228183
#
# Linha 12: Nov-19,1816857,0,57,11.3,218723
#
# Linha 13: dez-19,1780927,0,57,11.1,233063
#
# Linha 14: Jan-20,1677734,0,56,11.4,171155
#
# Linha 15: fev-20,1600103,0,56,11.8,179925
#
# Linha 16: Mar-20,1237047,0,55,12.4,146460
#
# Linha 17: abr-20,381635,1,53,12.7,47368
#
# Linha 18: mai-20,425965,1,51,13.1,52396
#
# Linha 19: Jun-20,546194,1,50,13.6,115726
#
# Linha 20: Jul-20,635585,1,49,14.1,155692
#
# Linha 21: ago-20,662590,1,49,14.8,165524
#
# Linha 22: set-20,724707,1,49,14.9,188514
#
# Linha 23: out-20,830993,1,50,14.6,196045
#
# Linha 24: Nov-20,844084,1,51,14.4,205097
#
# Linha 25: dez-20,872479,1,51,14.2,222916
#
# Linha 26: Jan-21,774720,1,51,14.5,154986
#
# Linha 27: fev-21,743926,1,51,14.6,153654
#
# Linha 28: Mar-21,741405,1,51,14.9,172024
#
# Linha 29: abr-21,679473,1,51,14.8,157976
#
# Linha 30: mai-21,824203,1,51,14.7,169237
#
# Linha 31: Jun-21,847407,1,52,14.2,158059
#
# Linha 32: Jul-21,870466,1,53,13.7,150973
#
# Linha 33: ago-21,987909,0,53,13.1,149456
#
# Linha 34: set-21,1018489,0,54,12.6,133164
#
# Linha 35: out-21,1058578,0,55,12.1,140375
#
# Linha 36: Nov-21,1121413,0,55,11.6,148304
#
# Linha 37: dez-21,1156025,0,56,11.1,177865
#
# Linha 38: Jan-22,1009370,0,55,11.2,108397
#
# Linha 39: fev-22,1059977,0,55,11.2,117121
#
# Linha 40: Mar-22,1246519,0,55,11.1,129060
#
# Linha 41: abr-22,1160414,0,56,10.5,128362
#
# Linha 42: mai-22,1305969,0,56,9.8,164228
#
# Linha 43: Jun-22,1197695,0,57,9.3,151203
#
# Linha 44: Jul-22,1166565,0,57,9.1,159259
#
# Linha 45: ago-22,1300422,0,57,8.9,184506
#
# Linha 46: set-22,1198690,0,57,8.7,168802
#
# Linha 47: out-22,1228571,0,57,8.3,158866
#
# Linha 48: Nov-22,1174381,0,57,8.1,174009
#
# Linha 49: dez-22,1149591,0,57,7.9,187179
#
# Linha 50: Jan-23,1138935,0,57,8.4,122410
